# %% [markdown]
#  Exercise 2.01: Text Cleaning and Tokenization

# %%
import re

# %% [markdown]
#  3. Create a method called clean_text() that will delete all characters other
# than digits, alphabetical characters, and whitespaces from the text and split
# the text into tokens. For this, we will use the text which matches with all
# non-alphanumeric characters, and we will replace all of them with an
# empty string:

# %%
def clean_text(sentence):
 return re.sub(r'([^\s\w]|_)+', ' ', sentence).split()

# %% [markdown]
#  4. Store the sentence to be cleaned in a variable named sentence and pass it
# through the preceding function. Add the following code to this: implement

# %%
sentence = 'Sunil tweeted, "Witnessing 70th Republic Day "\
 "of India from Rajpath, New Delhi. "\
 "Mesmerizing performance by Indian Army! "\
 "Awesome airshow! @india_official "\
 "@indian_army #India #70thRepublic_Day. "\
 "For more photos ping me sunil@photoking.com :)"'
clean_text(sentence)
# Out:
# ['Sunil',
#  'tweeted',
#  'Witnessing',
#  '70th',
#  'Republic',
#  'Day',
#  'of',
#  'India',
#  'from',
#  'Rajpath',
#  'New',
#  'Delhi',
#  'Mesmerizing',
#  'performance',
#  'by',
#  'Indian',
#  'Army',
#  'Awesome',
#  'airshow',
#  'india',
#  'official',
#  'indian',
#  'army',
#  'India',
#  '70thRepublic',
#  'Day',
#  'For',
#  'more',
#  'photos',
#  'ping',
#  'me',
#  'sunil',
#  'photoking',
#  'com']

# %% [markdown]
# Exercise 2.02: Extrating N-Grams

# %%
import re
def n_gram_extractor(sentence, n):
    tokens = re.sub(r'([^\s\w]|_)+', ' ', sentence).split()
    for i in range(len(tokens)-n+1):
        print(tokens[i:i+n])

# %% [markdown]
# If n is 2, two consecutive tokens will be taken, resulting in bigrams. To check the
# bigrams, we pass the function the text and with n=2. Add the following code to
# do this:

# %%
n_gram_extractor('The cute little boy is playing with the kitten.', \
                 2)
# Out:
# ['The', 'cute']
# ['cute', 'little']
# ['little', 'boy']
# ['boy', 'is']
# ['is', 'playing']
# ['playing', 'with']
# ['with', 'the']
# ['the', 'kitten']

# %% [markdown]
# To check the trigrams, 3

# %%
n_gram_extractor('The cute little boy is playing with the kitten.', \
                 2)
# Out:
# ['The', 'cute']
# ['cute', 'little']
# ['little', 'boy']
# ['boy', 'is']
# ['is', 'playing']
# ['playing', 'with']
# ['with', 'the']
# ['the', 'kitten']

# %% [markdown]
# Nltk imort ngrams

# %%
from nltk import ngrams
list(ngrams('The cute little boy is playing with the kitten.'\
            .split(), 2))
# Out:
# [('The', 'cute'),
#  ('cute', 'little'),
#  ('little', 'boy'),
#  ('boy', 'is'),
#  ('is', 'playing'),
#  ('playing', 'with'),
#  ('with', 'the'),
#  ('the', 'kitten.')]

# %% [markdown]
# 6. To check the trigrams using the nltk library, add the following code:

# %%
list(ngrams('The cute little boy is playing with the kitten.'.split(), 3))
# Out:
# [('The', 'cute', 'little'),
#  ('cute', 'little', 'boy'),
#  ('little', 'boy', 'is'),
#  ('boy', 'is', 'playing'),
#  ('is', 'playing', 'with'),
#  ('playing', 'with', 'the'),
#  ('with', 'the', 'kitten.')]

# %% [markdown]
#  7. To check the bigrams using the textblob library, add the following code:

# %%
# !pip install -U textblob
# Out:
# Requirement already satisfied: textblob in c:\users\ayazn\miniconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\ayazn\miniconda3\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\ayazn\miniconda3\lib\site-packages (from nltk>=3.9->textblob) (8.2.1)
# Requirement already satisfied: joblib in c:\users\ayazn\miniconda3\lib\site-packages (from nltk>=3.9->textblob) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ayazn\miniconda3\lib\site-packages (from nltk>=3.9->textblob) (2025.9.18)
# Requirement already satisfied: tqdm in c:\users\ayazn\miniconda3\lib\site-packages (from nltk>=3.9->textblob) (4.66.5)
# Requirement already satisfied: colorama in c:\users\ayazn\miniconda3\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)

# %%
# !pip install -U textblob
from textblob import TextBlob
import nltk

# Download both punkt and punkt_tab to fix the LookupError
nltk.download('punkt')
nltk.download('punkt_tab')

blob = TextBlob("The cute little boy is playing with the kitten.")
bigrams = blob.ngrams(n=2)
print("--------")
print(bigrams)
print("--------")
# Out:
# Requirement already satisfied: textblob in c:\users\ayazn\miniconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\ayazn\miniconda3\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\ayazn\miniconda3\lib\site-packages (from nltk>=3.9->textblob) (8.2.1)
# Requirement already satisfied: joblib in c:\users\ayazn\miniconda3\lib\site-packages (from nltk>=3.9->textblob) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ayazn\miniconda3\lib\site-packages (from nltk>=3.9->textblob) (2025.9.18)
# Requirement already satisfied: tqdm in c:\users\ayazn\miniconda3\lib\site-packages (from nltk>=3.9->textblob) (4.66.5)
# Requirement already satisfied: colorama in c:\users\ayazn\miniconda3\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# --------
# [WordList(['The', 'cute']), WordList(['cute', 'little']), WordList(['little', 'boy']), WordList(['boy', 'is']), WordList(['is', 'playing']), WordList(['playing', 'with']), WordList(['with', 'the']), WordList(['the', 'kitten'])]
# --------
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ayazn\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ayazn\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# Exercise 2.03 Keras

# %%
# !pip install tensorflow
from tensorflow.keras.preprocessing.text import text_to_word_sequence
from textblob import TextBlob

sentence = ('Sunil tweeted, "Witnessing 70th Republic Day '
            'of India from Rajpath, New Delhi. '
            'Mesmerizing performance by Indian Army! '
            'Awesome airshow! @india_official '
            '@indian_army #India #70thRepublic_Day. '
            'For more photos ping me sunil@photoking.com :)"')

# Tokenize sentence
tokens = text_to_word_sequence(sentence)
print("Word Sequence:", tokens)

# TextBlob for extra analysis
blob = TextBlob(sentence)
print("\nNoun Phrases:", blob.noun_phrases)
print("Sentiment:", blob.sentiment)

# %%
def get_keras_tokens(text):
 return text_to_word_sequence(text)
get_keras_tokens(sentence)

# %%
def get_textblob_tokens(text):
 blob = TextBlob(text)
 return blob.words
get_textblob_tokens(sentence)

# %% [markdown]
#  Exercise 2.04: Tokenizing Text Using Various Tokenizers

# %%
from nltk.tokenize import TweetTokenizer
from nltk.tokenize import MWETokenizer
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import WhitespaceTokenizer
from nltk.tokenize import WordPunctTokenizer
sentence = 'Sunil tweeted, "Witnessing 70th Republic Day "\
            "of India from Rajpath, New Delhi. "\
            "Mesmerizing performance by Indian Army! "\
            "Awesome airshow! @india_official "\
            "@indian_army #India #70thRepublic_Day. "\
            "For more photos ping me sunil@photoking.com :)"'

# %% [markdown]
# TweetTokenizer

# %%
def tokenize_with_tweet_tokenizer(text):
    # Here will create an object of tweetTokenizer
    tweet_tokenizer = TweetTokenizer() 
    """
    Then we will call the tokenize method of 
    tweetTokenizer which will return token list of sentences.
    """
    return tweet_tokenizer.tokenize(text) 
tokenize_with_tweet_tokenizer(sentence)
# Out:
# ['Sunil',
#  'tweeted',
#  ',',
#  '"',
#  'Witnessing',
#  '70th',
#  'Republic',
#  'Day',
#  '"',
#  '"',
#  'of',
#  'India',
#  'from',
#  'Rajpath',
#  ',',
#  'New',
#  'Delhi',
#  '.',
#  '"',
#  '"',
#  'Mesmerizing',
#  'performance',
#  'by',
#  'Indian',
#  'Army',
#  '!',
#  '"',
#  '"',
#  'Awesome',
#  'airshow',
#  '!',
#  '@india_official',
#  '"',
#  '"',
#  '@indian_army',
#  '#India',
#  '#70thRepublic_Day',
#  '.',
#  '"',
#  '"',
#  'For',
#  'more',
#  'photos',
#  'ping',
#  'me',
#  'sunil@photoking.com',
#  ':)',
#  '"']

# %% [markdown]
# MWETokenizer

# %%
def tokenize_with_mwe(text):
 mwe_tokenizer = MWETokenizer([('Republic', 'Day')])
 mwe_tokenizer.add_mwe(('Indian', 'Army'))
 return mwe_tokenizer.tokenize(text.split())
tokenize_with_mwe(sentence)
# Out:
# ['Sunil',
#  'tweeted,',
#  '"Witnessing',
#  '70th',
#  'Republic_Day',
#  '"',
#  '"of',
#  'India',
#  'from',
#  'Rajpath,',
#  'New',
#  'Delhi.',
#  '"',
#  '"Mesmerizing',
#  'performance',
#  'by',
#  'Indian',
#  'Army!',
#  '"',
#  '"Awesome',
#  'airshow!',
#  '@india_official',
#  '"',
#  '"@indian_army',
#  '#India',
#  '#70thRepublic_Day.',
#  '"',
#  '"For',
#  'more',
#  'photos',
#  'ping',
#  'me',
#  'sunil@photoking.com',
#  ':)"']

# %%
tokenize_with_mwe(sentence.replace('!',''))
# Out:
# ['Sunil',
#  'tweeted,',
#  '"Witnessing',
#  '70th',
#  'Republic_Day',
#  '"',
#  '"of',
#  'India',
#  'from',
#  'Rajpath,',
#  'New',
#  'Delhi.',
#  '"',
#  '"Mesmerizing',
#  'performance',
#  'by',
#  'Indian_Army',
#  '"',
#  '"Awesome',
#  'airshow',
#  '@india_official',
#  '"',
#  '"@indian_army',
#  '#India',
#  '#70thRepublic_Day.',
#  '"',
#  '"For',
#  'more',
#  'photos',
#  'ping',
#  'me',
#  'sunil@photoking.com',
#  ':)"']

# %% [markdown]
#  text using the regular expression tokenizer

# %%
def tokenize_with_regex_tokenizer(text):
 reg_tokenizer = RegexpTokenizer('\w+|\$[\d\.]+|\S+')
 return reg_tokenizer.tokenize(text)
tokenize_with_regex_tokenizer(sentence)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\ayazn\AppData\Local\Temp\ipykernel_20528\619223973.py:2: SyntaxWarning: invalid escape sequence '\w'
#   reg_tokenizer = RegexpTokenizer('\w+|\$[\d\.]+|\S+')
# ['Sunil',
#  'tweeted',
#  ',',
#  '"Witnessing',
#  '70th',
#  'Republic',
#  'Day',
#  '"',
#  '"of',
#  'India',
#  'from',
#  'Rajpath',
#  ',',
#  'New',
#  'Delhi',
#  '.',
#  '"',
#  '"Mesmerizing',
#  'performance',
#  'by',
#  'Indian',
#  'Army',
#  '!',
#  '"',
#  '"Awesome',
#  'airshow',
#  '!',
#  '@india_official',
#  '"',
#  '"@indian_army',
#  '#India',
#  '#70thRepublic_Day.',
#  '"',
#  '"For',
#  'more',
#  'photos',
#  'ping',
#  'me',
#  'sunil',
#  '@photoking.com',
#  ':)"']

# %% [markdown]
# To tokenize the text using the whitespace tokenizer

# %%
def tokenize_with_wst(text):
 wh_tokenizer = WhitespaceTokenizer()
 return wh_tokenizer.tokenize(text)
tokenize_with_wst(sentence)
# Out:
# ['Sunil',
#  'tweeted,',
#  '"Witnessing',
#  '70th',
#  'Republic',
#  'Day',
#  '"',
#  '"of',
#  'India',
#  'from',
#  'Rajpath,',
#  'New',
#  'Delhi.',
#  '"',
#  '"Mesmerizing',
#  'performance',
#  'by',
#  'Indian',
#  'Army!',
#  '"',
#  '"Awesome',
#  'airshow!',
#  '@india_official',
#  '"',
#  '"@indian_army',
#  '#India',
#  '#70thRepublic_Day.',
#  '"',
#  '"For',
#  'more',
#  'photos',
#  'ping',
#  'me',
#  'sunil@photoking.com',
#  ':)"']

# %% [markdown]
# To tokenize the text using the Word Punct tokenizer

# %%
def tokenize_with_wordpunct_tokenizer(text):
 wp_tokenizer = WordPunctTokenizer()
 return wp_tokenizer.tokenize(text)
tokenize_with_wordpunct_tokenizer(sentence)
# Out:
# ['Sunil',
#  'tweeted',
#  ',',
#  '"',
#  'Witnessing',
#  '70th',
#  'Republic',
#  'Day',
#  '"',
#  '"',
#  'of',
#  'India',
#  'from',
#  'Rajpath',
#  ',',
#  'New',
#  'Delhi',
#  '.',
#  '"',
#  '"',
#  'Mesmerizing',
#  'performance',
#  'by',
#  'Indian',
#  'Army',
#  '!',
#  '"',
#  '"',
#  'Awesome',
#  'airshow',
#  '!',
#  '@',
#  'india_official',
#  '"',
#  '"@',
#  'indian_army',
#  '#',
#  'India',
#  '#',
#  '70thRepublic_Day',
#  '.',
#  '"',
#  '"',
#  'For',
#  'more',
#  'photos',
#  'ping',
#  'me',
#  'sunil',
#  '@',
#  'photoking',
#  '.',
#  'com',
#  ':)"']

# %% [markdown]
# Exercise 2.05: Converting Words in the Present Continuous Tense into Base
# Words with RegexpStemmer

# %%
from nltk import RegexpStemmer

# %%
def get_stem(text):
    # only apply stemming if word length is 4 
    regex_stemmer = RegexpStemmer('ing$', min=4)
    return ' '.join([regex_stemmer.stem(wd) for \
                     wd in text.split()])

# %% [markdown]
# Exercise 2.06: Using the Porter Stemmer

# %%
from nltk.stem.porter import *
sentence = "Before eating, it would be nice to "\
 "sanitize your hands with a sanitizer"

# %%
def get_stems(text):
 ps_stemmer = PorterStemmer()
 return ' '.join([ps_stemmer.stem(wd) for \
 wd in text.split()])
get_stems(sentence)
# Out:
# 'befor eating, it would be nice to sanit your hand with a sanit'

# %% [markdown]
# Lemmatization

# %% [markdown]
# Exercise 2.07:

# %% [markdown]
# Import nltk and its related packages, and then declare a sentence variable.

# %%
 import nltk
 from nltk.stem import WordNetLemmatizer
 from nltk import word_tokenize
 nltk.download('wordnet')
 nltk.download('punkt')
 sentence = "The products produced by the process today are "\
           "far better than what it produces generally."
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ayazn\AppData\Roaming\nltk_data...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 4
#       2 from nltk.stem import WordNetLemmatizer
#       3 from nltk import word_tokenize
# ----> 4 nltk.download('wordnet')
#       5 nltk.download('punkt')
#       6 sentence = "The products produced by the process today are "\
#       7           "far better than what it produces generally."
#
# File c:\Users\ayazn\miniconda3\Lib\site-packages\nltk\downloader.py:774, in Downloader.download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
#     765 def show(s, prefix2=""):
#     766     print_to(
#     767         textwrap.fill(
#     768             s,
#    (...)    771         )
#     772     )
# --> 774 for msg in self.incr_download(info_or_id, download_dir, force):
#     775     # Error messages
#     776     if isinstance(msg, ErrorMessage):
#     777         show(msg.message)
#
# File c:\Users\ayazn\miniconda3\Lib\site-packages\nltk\downloader.py:642, in Downloader.incr_download(self, info_or_id, download_dir, force)
#     638     yield FinishCollectionMessage(info)
#     640 # Handle Packages (delegate to a helper function).
#     641 else:
# --> 642     yield from self._download_package(info, download_dir, force)
#
# File c:\Users\ayazn\miniconda3\Lib\site-packages\nltk\downloader.py:710, in Downloader._download_package(self, info, download_dir, force)
#     708 num_blocks = max(1, info.size / (1024 * 16))
#     709 for block in itertools.count():
# --> 710     s = infile.read(1024 * 16)  # 16k blocks.
#     711     outfile.write(s)
#     712     if not s:
#
# File c:\Users\ayazn\miniconda3\Lib\http\client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File c:\Users\ayazn\miniconda3\Lib\socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File c:\Users\ayazn\miniconda3\Lib\ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\ayazn\miniconda3\Lib\ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# To lemmatize the tokens, we extracted from the sentence, add the
# following code:

# %%
lemmatizer = WordNetLemmatizer()
def get_lemmas(text):
    lemmatizer = WordNetLemmatizer()
    return ' '.join([lemmatizer.lemmatize(word) for \
                     word in word_tokenize(text)])
get_lemmas(sentence)

# %% [markdown]
# Exercise 2.08: Singularizing and Pluralizing Words

# %%
from textblob import TextBlob
sentence = TextBlob('She sells seashells on the seashore')

# %% [markdown]
# list of words in the sentence

# %%
sentence.words
# Out:
# WordList(['She', 'sells', 'seashells', 'on', 'the', 'seashore'])

# %% [markdown]
#  singularize the third word in the sentence

# %%
def singularize(word):
    return word.singularize()
singularize(sentence.words[2])
# Out:
# 'seashell'

# %% [markdown]
# To pluralize the fifth word in the given sentence

# %%
def pluralize(word):
    return word.pluralize()
pluralize(sentence.words[5])
# Out:
# 'seashores'

# %% [markdown]
#  Exercise 2.09: Language Translation
